# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
#Directory Image    Note: \->/
my_path = 'C:/Users/admin/Desktop/Tu-hoc-main/Tu-hoc-main/ComputerVision/img/01/1.jpg'

# %%
#Read image
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
#Current size
print(img.size)
# Out:
# (500, 332)

# %%
#Change image size (Not change image in folder)
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
#Change image size (Change image in folder)
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x33>
