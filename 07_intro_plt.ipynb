# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
#Directory Image    Note: \->/
my_path = 'C:/Users/admin/Desktop/Tu-hoc-main/Tu-hoc-main/ComputerVision/img/01/1.jpg'

im = Image.open(my_path)

plt.imshow(im)

# %%
x = [1,2,3,4,5]
y = [10,16,20,30,25]
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [10,16,20,30,25]
plt.plot(x,y,color = 'red')
plt.title("Bieu do")
plt.axis('off') #Tat truc toa do
plt.show()

# %%
im = Image.open(my_path)

x = [100,200,300,400]
y = [200,300,200,300]

plt.imshow(im)
plt.plot(x,y,'r*') #Danh dau cac diem x,y
plt.plot(x,y, 'ys:')
plt.show()
