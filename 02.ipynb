# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
#Directory Image    Note: \->/
my_dir = 'C:/Users/admin/Desktop/Tu-hoc-main/Tu-hoc-main/ComputerVision/img/01'

# %%
imgs = get_image_list(my_dir)

# %%
for img in imgs:
    print("Size" , img.size)
    display(img)
# Out:
# Size (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# Size (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# Size (500, 375)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>
# Size (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# Size (500, 332)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x332>
